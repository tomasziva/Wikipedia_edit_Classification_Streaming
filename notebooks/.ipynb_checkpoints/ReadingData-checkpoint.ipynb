# %%
from pyspark.streaming import StreamingContext

# %%
f = sc.textFile("file:///C:/Pr/AA_Big_Data/Assignment_3/spark/save_data/myoutput-1587841650000/part-00001")
# sc.textFile("file:///C:/Pr/AA_Big_Data/Assignment_3/spark/save_data/myoutput-1587841650000/part-00[0-5]*")
# wc = f.flatMap(lambda x: x.split(' ')).map(lambda x: (x, 1)).reduceByKey(add)

# %%
# f.flatMap(lambda xs: [(x, 1) for x in xs])
# ratings = f.map(lambda l: l.split(','))
f_words = f.flatMap(lambda l: l.split(','))

# %%
for xs in f.take(100):
    for x in xs:
        print(x)
# Out:
# {
# "
# t
# i
# t
# l
# e
# _
# p
# a
# g
# e
# "
# :
#
# "
# 9
# 2
# n
# d
#
# I
# l
# l
# i
# n
# o
# i
# s
#
# V
# o
# l
# u
# n
# t
# e
# e
# r
#
# I
# n
# f
# a
# n
# t
# r
# y
#
# R
# e
# g
# i
# m
# e
# n
# t
# "
# ,
#
# "
# t
# e
# x
# t
# _
# n
# e
# w
# "
# :
#
# "
# {
# {
# I
# n
# f
# o
# b
# o
# x
#
# m
# i
# l
# i
# t
# a
# r
# y
#
# u
# n
# i
# t
# \
# n
# |
# u
# n
# i
# t
# _
# n
# a
# m
# e
# =
#
# 9
# 2
# n
# d
#
# R
# e
# g
# i
# m
# e
# n
# t
# ,
#
# I
# l
# l
# i
# n
# o
# i
# s
#
# V
# o
# l
# u
# n
# t
# e
# e
# r
#
# I
# n
# f
# a
# n
# t
# r
# y
# /
# \
# n
# |
#
# i
# m
# a
# g
# e
# =
# F
# l
# a
# g
#
# o
# f
#
# I
# l
# l
# i
# n
# o
# i
# s
# .
# s
# v
# g
# \
# n
# |
#
# i
# m
# a
# g
# e
# _
# s
# i
# z
# e
#
# =
#
# 1
# 0
# 0
# \
# n
# |
# c
# a
# p
# t
# i
# o
# n
# =
# I
# l
# l
# i
# n
# o
# i
# s
#
# s
# t
# a
# t
# e
#
# f
# l
# a
# g
# \
# n
# |
# d
# a
# t
# e
# s
# =
#
# S
# e
# p
# t
# e
# m
# b
# e
# r
#
# 4
# ,
#
# 1
# 8
# 6
# 2
# ,
#
# t
# ...

# %%
parsedData = f.map(lambda line: array([float(x) for x in line.split(',')]))

# %%
print("The first element in spam_words is", f_words.first())
# Out:
# The first element in spam_words is {"title_page": "92nd Illinois Volunteer Infantry Regiment"

# %%
print(f_words.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8c328a66c544> in <module>
# ----> 1 print(f_words.columns)
#
# AttributeError: 'PipelinedRDD' object has no attribute 'columns'
