# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from threading import Thread

class StreamingThread(Thread):
    def __init__(self, ssc):
        Thread.__init__(self)
        self.ssc = ssc
    def run(self):
        ssc.start()
        ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-3RFUG6S:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType
import pyspark.sql.functions as F
from pyspark.sql.types import *

# %%
# DIFFERENCE BETWEEN OLD AND NEW TEXT

import difflib

def make_diff(old, new):
    diff = difflib.ndiff(old, new)
    delta = ''.join(x[2:] for x in diff if x.startswith('- ') or x.startswith('+'))
    return delta

# %%
# LOAD IN THE SAVED PIPELINE

from pyspark.ml import PipelineModel

globals()['my_tfidf'] = PipelineModel.load('models/best/tfidf')

# %%
# LOAD IN THE MODEL IF NOT YET LOADED

from pyspark.ml.classification import LogisticRegressionModel

globals()['models_loaded'] = False

if not globals()['models_loaded']:
    globals()['my_model'] = LogisticRegressionModel.load('models/best/logistic_regression_with_weights_and_comment')
    globals()['models_loaded'] = True

# %%
# DEFINE PREDICTION FUNCTION

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df.show()
    
    # Get difference between old and new texts
    udfmake_diff = F.udf(make_diff, StringType())
    df_difference = df.withColumn("difference", lit(udfmake_diff("text_old", "text_new")))
  
    # Change column name from 'label' to 'label_string' for convenience
    df_wd = df_difference.withColumnRenamed('label', 'label_string')
    
    # Fit the loaded pipeline
    dataset = globals()['my_tfidf'].transform(df_wd)
    dataset.select("difference", "comment", "features_diff", "features_comment", "features", "label").show()
       
    # Predict using the loaded model: 
    df_pred = globals()['my_model'].transform(dataset)
    df_final_prediction = df_pred.withColumn("prediction_string", F.when(df_pred.prediction == 0, "safe").when(df_pred.prediction == 1, "unsafe").otherwise("vandal"))
    df_final_prediction.select("comment", "difference", "probability", "label", "label_string", "prediction", "prediction_string").show()

# %%
# SELECT STREAMING INTERVAL
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
# CLASSIFY INCOMING EDITS
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2020-05-31 22:57:20 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|        Masaya Honda|//en.wikipedia.or...|
# |→‎Descriptions in...| safe|Gre regiment|[[File:Fight Pygm...|[[File:Fight Pygm...|Pygmy (Greek myth...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |                [[]]|→‎Descriptions in...|       (10000,[],[])|(10000,[2482,7586...|(20000,[2482,7586...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |→‎Descriptions in...|                [[]]|[0.54739470418626...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:57:30 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |→‎Qualifications ...| safe| Pokeswap|The '''Chief Priv...|The '''Chief Priv...|Chief privacy off...|//en.wikipedia.or...|
# |            →‎Career| safe|     Ytkr|{{Multiple issues...|{{Multiple issues...|        Sudendu Shah|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +----------+--------------------+-------------+--------------------+--------------------+-----+
# |difference|             comment|features_diff|    features_comment|            features|label|
# +----------+--------------------+-------------+--------------------+--------------------+-----+
# |        }}|→‎Qualifications ...|(10000,[],[])|(10000,[5396,6319...|(20000,[5396,6319...|  0.0|
# |       he |            →‎Career|(10000,[],[])|(10000,[2566],[4....|(20000,[2566],[4....|  0.0|
# +----------+--------------------+-------------+--------------------+--------------------+-----+
#
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |             comment|difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |→‎Qualifications ...|        }}|[2.93897577671134...|  0.0|        safe|       1.0|           unsafe|
# |            →‎Career|       he |[0.89724028386858...|  0.0|        safe|       0.0|             safe|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:57:40 =========
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|     title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|Hiroya Kiyomoto|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...| Kenta Kakimoto|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use mdy dates|d...|   Tomoki Menda|//en.wikipedia.or...|
# |Addingshort descr...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|   Tomoyuki Doi|//en.wikipedia.or...|
# |It's regarding th...| safe|   Mir Ali19|{{short descripti...|{{short descripti...|  PM CARES Fund|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Addingshort descr...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |{{short descripti...|Addingshort descr...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |
#
# <br />
#
# == '''P...|It's regarding th...|(10000,[551,574,6...|(10000,[2197,2445...|(20000,[2197,2445...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Addingshort descr...|{{short descripti...|[0.99999768659342...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Addingshort descr...|{{short descripti...|[0.99999768659342...|  0.0|        safe|       0.0|             safe|
# |It's regarding th...|
#
# <br />
#
# == '''P...|[0.99999999999962...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:57:50 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|           Sho Asuke|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|Makoto Watanabe (...|//en.wikipedia.or...|
# |Removed Taro hype...| safe| SonorianBnS|{{short descripti...|{{short descripti...|         Robert Capa|//en.wikipedia.or...|
# |                    | safe|      Carnby|'''Redding''' may...|'''Redding''' may...|             Redding|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |                [[]]|Removed Taro hype...|       (10000,[],[])|(10000,[1512,3779...|(20000,[1512,3779...|  0.0|
# |     l'Reddke Reddi'|                    |(10000,[4006,4848...|       (10000,[],[])|(20000,[14006,148...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Removed Taro hype...|                [[]]|[1.0,4.1115829071...|  0.0|        safe|       0.0|             safe|
# |                    |     l'Reddke Reddi'|[0.74852706638691...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:58:00 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|        Genta Matsuo|//en.wikipedia.or...|
# |        →‎References| safe|       WDM10|{{short descripti...|{{short descripti...|List of current N...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|     Masato Katayama|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |<ref>{{cite web|t...|        →‎References|(10000,[65,204,52...|(10000,[6125],[3....|(20000,[6125,1006...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |        →‎References|<ref>{{cite web|t...|[0.99999999996665...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:58:10 =========
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|     title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|  Yuji Kishioku|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|Kensuke Tsukuda|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+---------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:58:20 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|Nobuyuki Oishi (f...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Infobox footbal...|       Masaya Karube|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,1654,...|(20000,[205,1654,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Adding localshort...|{{short descripti...|[1.0,3.0858854779...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# ========= 2020-05-31 22:58:30 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |cleanup,typo(s) f...| safe| Kaltenmeyer|{{short descripti...|{{short descripti...|Enclosed religiou...|//en.wikipedia.or...|
# |Adding localshort...| safe|Red Director|{{short descripti...|{{Use dmy dates|d...|      Daiki Matsuoka|//en.wikipedia.or...|
# |Fixed a typo foun...| safe| Ira Leviton|{{About|the Frenc...|{{About|the Frenc...|      Accolay, Yonne|//en.wikipedia.or...|
# |→‎Criticism:chang...| safe|  Geysirhead|{{short descripti...|{{short descripti...|             H-index|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |             ai ct  |cleanup,typo(s) f...|(10000,[4602,9362...|(10000,[947,2064,...|(20000,[947,2064,...|  0.0|
# |{{short descripti...|Adding localshort...|(10000,[205,964,8...|(10000,[205,2626,...|(20000,[205,2626,...|  0.0|
# |CCOLAYccolayETetS...|Fixed a typo foun...|(10000,[7600,7819...|(10000,[659,1384,...|(20000,[659,1384,...|  0.0|
# |does not provide ...|→‎Criticism:chang...|(10000,[232,300,3...|(10000,[870,1698,...|(20000,[870,1698,...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |cleanup,typo(s) f...|             ai ct  |[1.0,4.5530945097...|  0.0|        safe|       0.0|             safe|
# |Adding localshort...|{{short descripti...|[1.0,1.3932052190...|  0.0|        safe|       0.0|             safe|
# |Fixed a typo foun...|CCOLAYccolayETetS...|[1.0,8.2266717658...|  0.0|        safe|       0.0|             safe|
# |→‎Criticism:chang...|does not provide ...|[1.0,1.0452012494...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:58:40 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |Added music video...| safe|LauriePedia|{{DISPLAYTITLE:Th...|{{DISPLAYTITLE:Th...|The Cursed Earth ...|//en.wikipedia.or...|
# |→‎Political posit...| safe|    Sal2100|{{use mdy dates |...|{{use mdy dates |...|        Jo Jorgensen|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# | In popular cultu...|Added music video...|(10000,[65,524,57...|(10000,[1384,1526...|(20000,[1384,1526...|  0.0|
# |bo[[Tderump|borde...|→‎Political posit...|(10000,[1247,2503...|(10000,[8120,9824...|(20000,[8120,9824...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Added music video...| In popular cultu...|[1.0,1.0680423102...|  0.0|        safe|       0.0|             safe|
# |→‎Political posit...|bo[[Tderump|borde...|[0.00719589131927...|  0.0|        safe|       1.0|           unsafe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:59:00 =========
# +-------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +-------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |       | safe|Citadel2811|{{Expand German|R...|{{Expand German|R...|Reich Ministry of...|//en.wikipedia.or...|
# +-------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +----------+-------+--------------------+----------------+--------------------+-----+
# |difference|comment|       features_diff|features_comment|            features|label|
# +----------+-------+--------------------+----------------+--------------------+-----+
# |<br/><br/>|       |(10000,[8482],[8....|   (10000,[],[])|(20000,[18482],[8...|  0.0|
# +----------+-------+--------------------+----------------+--------------------+-----+
#
# +-------+----------+--------------------+-----+------------+----------+-----------------+
# |comment|difference|         probability|label|label_string|prediction|prediction_string|
# +-------+----------+--------------------+-----+------------+----------+-----------------+
# |       |<br/><br/>|[0.56936912767632...|  0.0|        safe|       0.0|             safe|
# +-------+----------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 22:59:10 =========
# +--------------------+------+---------------+--------------------+--------------------+-----------+--------------------+
# |             comment| label|      name_user|            text_new|            text_old| title_page|            url_page|
# +--------------------+------+---------------+--------------------+--------------------+-----------+--------------------+
# |→‎Can superflares...|  safe|      Bender235|{{about|the extra...|{{about|the extra...| Superflare|//en.wikipedia.or...|
# |                    |unsafe|Invisible Devil|{{Use dmy dates|d...|{{Use dmy dates|d...|Shampa Reza|//en.wikipedia.or...|
# +--------------------+------+---------------+--------------------+--------------------+-----------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          pdfabs.pdf|→‎Can superflares...|(10000,[789,4115]...|(10000,[20,427,95...|(20000,[20,427,95...|  0.0|
# | She is working a...|                    |(10000,[521,1368,...|       (10000,[],[])|(20000,[10521,113...|  1.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Can superflares...|          pdfabs.pdf|[1.0,1.7906498683...|  0.0|        safe|       0.0|             safe|
# |                    | She is working a...|[0.08762688090726...|  1.0|      unsafe|       1.0|           unsafe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# ========= 2020-05-31 23:04:20 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |added references ...| safe|   Lime44|{{Infobox album
# |...|{{Infobox album
# |...|Last Flight Home ...|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |[[|Tabla]]
# == Ref...|added references ...|(10000,[3997,6125...|(10000,[1384,6125...|(20000,[1384,6125...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |added references ...|[[|Tabla]]
# == Ref...|[0.99999999999957...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:04:30 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |→‎Energy usage an...| safe|  Bender235|{{Redirect|High-p...|{{Redirect|High-p...|       Supercomputer|//en.wikipedia.or...|
# |→‎Bayesian induct...| safe|  Bender235|{{Essay-like|date...|{{Essay-like|date...|Super-resolution ...|//en.wikipedia.or...|
# |removed orphan te...| safe|SFletcher06|{{short descripti...|{{short descripti...|Roy Brown (footba...|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          pdfabs.pdf|→‎Energy usage an...|(10000,[789,4115]...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# |        pdfabsv3.pdf|→‎Bayesian induct...|(10000,[4115,6809...|(10000,[20,569,17...|(20000,[20,569,17...|  0.0|
# |}}
# {{orphan|date=...|removed orphan te...|(10000,[879,1544,...|(10000,[1512,1544...|(20000,[1512,1544...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Energy usage an...|          pdfabs.pdf|[1.0,2.6318032874...|  0.0|        safe|       0.0|             safe|
# |→‎Bayesian induct...|        pdfabsv3.pdf|[1.0,5.8986929993...|  0.0|        safe|       0.0|             safe|
# |removed orphan te...|}}
# {{orphan|date=...|[0.99999978192239...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:04:40 =========
# +--------------------+------+-----------+--------------------+--------------------+-------------------+--------------------+
# |             comment| label|  name_user|            text_new|            text_old|         title_page|            url_page|
# +--------------------+------+-----------+--------------------+--------------------+-------------------+--------------------+
# |ReplacedarXivPDF ...|  safe|  Bender235|In geometry, a ''...|In geometry, a ''...|Substitution tiling|//en.wikipedia.or...|
# |                    |unsafe|Sourav duir|{{short descripti...|{{short descripti...|          Amit Shah|//en.wikipedia.or...|
# +--------------------+------+-----------+--------------------+--------------------+-------------------+--------------------+
#
# +------------+--------------------+--------------------+--------------------+--------------------+-----+
# |  difference|             comment|       features_diff|    features_comment|            features|label|
# +------------+--------------------+--------------------+--------------------+--------------------+-----+
# |pdfabspdfabs|ReplacedarXivPDF ...|(10000,[3837],[6....|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# |          20|                    |(10000,[3746],[2....|       (10000,[],[])|(20000,[13746],[2...|  1.0|
# +------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+------------+--------------------+-----+------------+----------+-----------------+
# |             comment|  difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+------------+--------------------+-----+------------+----------+-----------------+
# |ReplacedarXivPDF ...|pdfabspdfabs|[1.0,4.7480403239...|  0.0|        safe|       0.0|             safe|
# |                    |          20|[0.57808647162968...|  1.0|      unsafe|       0.0|             safe|
# +--------------------+------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:05:00 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |→‎Value judgment:...| safe|Bender235|{{redirect|Drug a...|{{redirect|Drug a...|     Substance abuse|//en.wikipedia.or...|
# |→‎References:Repl...| safe|Bender235|In [[mathematics]...|In [[mathematics]...|Subshift of finit...|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
# |difference|             comment|       features_diff|    features_comment|            features|label|
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
# |    pdfabs|→‎Value judgment:...|(10000,[789],[6.7...|(10000,[20,768,17...|(20000,[20,768,17...|  0.0|
# |    pdfabs|→‎References:Repl...|(10000,[789],[6.7...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |             comment|difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |→‎Value judgment:...|    pdfabs|[0.99999999999999...|  0.0|        safe|       0.0|             safe|
# |→‎References:Repl...|    pdfabs|[1.0,4.0243099244...|  0.0|        safe|       0.0|             safe|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# ========= 2020-05-31 23:05:10 =========
# +--------------------+-----+----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label| name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+----------+--------------------+--------------------+--------------------+--------------------+
# |Just have a wait ...| safe|LancedSoul|{{short descripti...|{{short descripti...|         Wish Dragon|//en.wikipedia.or...|
# |→‎Example:Replace...| safe| Bender235|[[File:SubpixelCi...|[[File:SubpixelCi...|Sub-pixel resolution|//en.wikipedia.or...|
# +--------------------+-----+----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |
# * [[Columbia Pic...|Just have a wait ...|(10000,[817,2728]...|(10000,[157,307,3...|(20000,[157,307,3...|  0.0|
# |              pdfabs|→‎Example:Replace...|(10000,[789],[6.7...|(10000,[20,1243,1...|(20000,[20,1243,1...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |Just have a wait ...|
# * [[Columbia Pic...|[1.0,2.9345900703...|  0.0|        safe|       0.0|             safe|
# |→‎Example:Replace...|              pdfabs|[1.0,1.5438059244...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:05:20 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |→‎References:Repl...| safe|Bender235|In [[probability ...|In [[probability ...|Sub-Gaussian dist...|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# ||}}[url =
#  }}PDF...|→‎References:Repl...|(10000,[3238,3535...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎References:Repl...||}}[url =
#  }}PDF...|[1.0,6.2027828857...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:05:50 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |→‎PPP:ReplacedarX...| safe|Bender235|In [[computationa...|In [[computationa...|                TFNP|//en.wikipedia.or...|
# |→‎References:Repl...| safe|Bender235|In [[mathematics]...|In [[mathematics]...|  Symplectic filling|//en.wikipedia.or...|
# |          →‎Research| safe| Mrbigtoe|{{short descripti...|{{short descripti...|Intracerebral hem...|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          pdfabs.pdf|→‎PPP:ReplacedarX...|(10000,[789,4115]...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# |{{A[https://axX|....|→‎References:Repl...|(10000,[964,3238,...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# |<ref name="pmid32...|          →‎Research|(10000,[15,258,43...|(10000,[9432],[7....|(20000,[9432,1001...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎PPP:ReplacedarX...|          pdfabs.pdf|[0.99999999999999...|  0.0|        safe|       0.0|             safe|
# |→‎References:Repl...|{{A[https://axX|....|[1.0,9.5931171796...|  0.0|        safe|       0.0|             safe|
# |          →‎Research|<ref name="pmid32...|[1.0,2.1954632197...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:06:00 =========
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
# |    update reference| safe|         Zyxw|{{short descripti...|{{short descripti...|      Raymond Bilney|//en.wikipedia.or...|
# |→‎External links:...| safe|Crouch, Swale|{{Distinguish|She...|{{Distinguish|She...|Shipley, West Yor...|//en.wikipedia.or...|
# |→‎External links:...| safe|    Bender235|{{Short descripti...|{{Short descripti...|Symmetry in quant...|//en.wikipedia.or...|
# +--------------------+-----+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          dlivad ...|    update reference|(10000,[4600,7193...|(10000,[2709,4343...|(20000,[2709,4343...|  0.0|
# |Towns in West Yor...|→‎External links:...|(10000,[224,1388,...|(10000,[586,1388,...|(20000,[586,1388,...|  0.0|
# |pdfabsv1.pdf arXi...|→‎External links:...|(10000,[2396,2801...|(10000,[20,586,17...|(20000,[20,586,17...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |    update reference|          dlivad ...|[1.0,7.8367286814...|  0.0|        safe|       0.0|             safe|
# |→‎External links:...|Towns in West Yor...|[1.0,1.9677280148...|  0.0|        safe|       0.0|             safe|
# |→‎External links:...|pdfabsv1.pdf arXi...|[1.0,1.4457771690...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# ========= 2020-05-31 23:06:10 =========
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|           name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |(→‎{{anchor|Histo...|unsafe|       49.205.34.203|{{cleanup|reason=...|{{cleanup|reason=...|History of Andhra...|//en.wikipedia.or...|
# |→‎External links:...|  safe|Elizabeth Linden ...|{{for|the Radio S...|{{for|the Radio S...|Wright-Patterson ...|//en.wikipedia.or...|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
# |difference|             comment|       features_diff|    features_comment|            features|label|
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
# |    ndukam|(→‎{{anchor|Histo...|(10000,[4051],[6....|(10000,[2765,3211...|(20000,[2765,3211...|  1.0|
# |         d|→‎External links:...|(10000,[9094],[4....|(10000,[586,3070,...|(20000,[586,3070,...|  0.0|
# +----------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |             comment|difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
# |(→‎{{anchor|Histo...|    ndukam|[0.99999999999999...|  1.0|      unsafe|       0.0|             safe|
# |→‎External links:...|         d|[0.99999995577604...|  0.0|        safe|       0.0|             safe|
# +--------------------+----------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:06:30 =========
# +--------------------+-----+----------+--------------------+--------------------+--------------+--------------------+
# |             comment|label| name_user|            text_new|            text_old|    title_page|            url_page|
# +--------------------+-----+----------+--------------------+--------------------+--------------+--------------------+
# |→‎Track listing:U...| safe|Hsn ahmadi|{{Infobox album
# |...|{{Infobox album
# |...|  White Stones|//en.wikipedia.or...|
# |→‎Applications:Re...| safe| Bender235|{{Multiple issues...|{{Multiple issues...|Swarm robotics|//en.wikipedia.or...|
# +--------------------+-----+----------+--------------------+--------------------+--------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |{Tr| clcss="wiita...|→‎Track listing:U...|(10000,[626,721,1...|(10000,[493,3222,...|(20000,[493,3222,...|  0.0|
# |              pdfabs|→‎Applications:Re...|(10000,[789],[6.7...|(10000,[20,1709,2...|(20000,[20,1709,2...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Track listing:U...|{Tr| clcss="wiita...|[1.0,5.0786765830...|  0.0|        safe|       0.0|             safe|
# |→‎Applications:Re...|              pdfabs|[1.0,2.5974915716...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-05-31 23:06:40 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |→‎References:Repl...| safe|  Bender235|{{textbook|date=S...|{{textbook|date=S...|Supersymmetric ga...|//en.wikipedia.or...|
# |→‎References in p...| safe|  Shaima596|{{short descripti...|{{short descripti...|Love in the Time ...|//en.wikipedia.or...|
# |Fixed a typo foun...| safe|Ira Leviton|{{About||the metr...|{{About||the metr...|               Accra|//en.wikipedia.or...|
# |→‎References:Repl...| safe|  Bender235|{{Multiple issues...|{{Multiple issues...|      Superpotential|//en.wikipedia.or...|
# ...
# |             comment|label|name_user|            text_new|            text_old|       title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+-----------------+--------------------+
# |→‎Aircraft on dis...| safe|  Noha307|{{Use dmy dates|d...|{{Use dmy dates|d...|Newark Air Museum|//en.wikipedia.or...|
# |→‎Winton train:bo...| safe|Tiptopper|{{short descripti...|{{short descripti...|  Nicholas Winton|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+-----------------+--------------------+
#
# +-------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |         difference|             comment|       features_diff|    features_comment|            features|label|
# +-------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |           -–-–-–-–|→‎Aircraft on dis...|       (10000,[],[])|(10000,[3260,4449...|(20000,[3260,4449...|  0.0|
# |ftended lsl inended|→‎Winton train:bo...|(10000,[816,1819,...|(10000,[941,2431,...|(20000,[941,2431,...|  0.0|
# +-------------------+--------------------+--------------------+--------------------+--------------------+-----+
# +--------------------+-------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|         difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+-------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Aircraft on dis...|           -–-–-–-–|[1.0,4.2946988290...|  0.0|        safe|       0.0|             safe|
# |→‎Winton train:bo...|ftended lsl inended|[0.99999999999239...|  0.0|        safe|       0.0|             safe|
# +--------------------+-------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-06-01 00:12:00 =========
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|          name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
# |       grammar tweak| safe|          Tim riley|{{Use Irish Engli...|{{Use Irish Engli...|        Honan Chapel|//en.wikipedia.or...|
# |<references group...| safe|        Davide King|{{use dmy dates|d...|{{use dmy dates|d...|  Far-right politics|//en.wikipedia.or...|
# |→‎Death of George...| safe|ArsenalAtletico2017|{{pp-vandalism|sm...|{{pp-vandalism|sm...|George Floyd prot...|//en.wikipedia.or...|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |                   '|       grammar tweak|       (10000,[],[])|(10000,[7669,8410...|(20000,[7669,8410...|  0.0|
# |rname=|nblower-al...|<references group...|(10000,[17,1811,2...|(10000,[1811,2788...|(20000,[1811,2788...|  0.0|
# |h[[H-|hog-tie]][[...|→‎Death of George...|(10000,[4578,5282...|(10000,[7207,7275...|(20000,[7207,7275...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |       grammar tweak|                   '|[0.99999999999865...|  0.0|        safe|       0.0|             safe|
# |<references group...|rname=|nblower-al...|[1.0,4.8884671658...|  0.0|        safe|       0.0|             safe|
# |→‎Death of George...|h[[H-|hog-tie]][[...|[0.99672396696883...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-06-01 00:12:10 =========
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|        name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
# |rephrased paragra...| safe|        Dmann1241|{{short descripti...|{{short descripti...|The Outsiders (film)|//en.wikipedia.or...|
# |                typo| safe|WereSpielChequers|{{about|the franc...|{{about|the franc...|          Scooby-Doo|//en.wikipedia.or...|
# |        Grammar Edit| safe|         Mark2627|{{Infobox person
# ...|{{Infobox person
# ...|       Mohamed Ashik|//en.wikipedia.or...|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |TAuteorsfilm's ca...|rephrased paragra...|(10000,[2,2197,24...|(10000,[1384,3968...|(20000,[1384,3968...|  0.0|
# |                   r|                typo|(10000,[7570],[4....|(10000,[7327],[3....|(20000,[7327,1757...|  0.0|
# |crmentiwworld rec...|        Grammar Edit|(10000,[246,949,2...|(10000,[7669,8666...|(20000,[7669,8666...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |rephrased paragra...|TAuteorsfilm's ca...|[0.99999999999672...|  0.0|        safe|       0.0|             safe|
# |                typo|                   r|[0.99999959723221...|  0.0|        safe|       0.0|             safe|
# |        Grammar Edit|crmentiwworld rec...|[0.99999999817177...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-06-01 00:12:20 =========
# +--------------------+------+-----------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|        name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-----------------+--------------------+--------------------+--------------------+--------------------+
# |(→‎First-person s...|unsafe|  190.178.207.227|{{short descripti...|{{short descripti...|         Game engine|//en.wikipedia.or...|
# |                    |  safe|        Arkhandar|{{short descripti...|{{short descripti...|    Rosalina (Mario)|//en.wikipedia.or...|
# |          →‎Military|  safe|      RickMoretti|{{short descripti...|{{short descripti...|         French name|//en.wikipedia.or...|
# |typo(s) fixed: Tr...|  safe|Chris the speller|{{about|the direc...|{{about|the direc...|Mayor of Greater ...|//en.wikipedia.or...|
# |updated figure to...|  safe|         Scheng23|{{DISPLAYTITLE:''...|{{DISPLAYTITLE:''...|            O-GlcNAc|//en.wikipedia.or...|
# +--------------------+------+-----------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |             RONALDO|(→‎First-person s...|(10000,[1069],[6....|(10000,[3183,5778...|(20000,[3183,5778...|  1.0|
# |Super 3DParty10World|                    |(10000,[1340,2659...|       (10000,[],[])|(20000,[11340,126...|  0.0|
# |Superiors address...|          →‎Military|(10000,[126,398,8...|(10000,[5877],[5....|(20000,[5877,1012...|  0.0|
# |- _Express|Transp...|typo(s) fixed: Tr...|(10000,[579,8962]...|(10000,[1139,1188...|(20000,[1139,1188...|  0.0|
# |   bright|alt=|alt=
# |updated figure to...|(10000,[1456,5196...|(10000,[2288,3587...|(20000,[2288,3587...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |(→‎First-person s...|             RONALDO|[1.43211468765088...|  1.0|      unsafe|       1.0|           unsafe|
# |                    |Super 3DParty10World|[0.96418490742483...|  0.0|        safe|       0.0|             safe|
# |          →‎Military|Superiors address...|[0.99999999984646...|  0.0|        safe|       0.0|             safe|
# |typo(s) fixed: Tr...|- _Express|Transp...|[1.0,7.1168850024...|  0.0|        safe|       0.0|             safe|
# |updated figure to...|   bright|alt=|alt=
# |[0.99999999738693...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# ========= 2020-06-01 00:12:30 =========
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|  title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
# |→‎Archaeological ...| safe| BMacZero|{{pp-protected|sm...|{{pp-protected|sm...|Qumran Caves|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |[[]][[ dynasty|He...|→‎Archaeological ...|(10000,[419,4756]...|(10000,[3219,6952...|(20000,[3219,6952...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Archaeological ...|[[]][[ dynasty|He...|[0.99999459416677...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-06-01 00:12:50 =========
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|  name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
# |→‎Captain Saberto...| safe|Carsten R D|{{Infobox zoo
# |zo...|{{Infobox zoo
# |zo...|Kristiansand Zoo ...|//en.wikipedia.or...|
# |→‎Casting:link added| safe|  Dmann1241|{{About|the James...|{{About|the James...|           Octopussy|//en.wikipedia.or...|
# +--------------------+-----+-----------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |[[File:Den sorte ...|→‎Captain Saberto...|(10000,[771,1992,...|(10000,[1082,1150...|(20000,[1082,1150...|  0.0|
# |               [[]]s|→‎Casting:link added|(10000,[2197],[2....|(10000,[1384,5066...|(20000,[1384,5066...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |→‎Captain Saberto...|[[File:Den sorte ...|[0.99999999930313...|  0.0|        safe|       0.0|             safe|
# |→‎Casting:link added|               [[]]s|[0.99992237115089...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
#
# ========= 2020-06-01 00:13:00 =========
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
# |preventing link r...| safe|   MPJ-DK|{{short descripti...|{{short descripti...|Distrito Federal ...|//en.wikipedia.or...|
# +--------------------+-----+---------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |          difference|             comment|       features_diff|    features_comment|            features|label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
# |202010/05/01/%C2%...|preventing link r...|(10000,[326,1880,...|(10000,[1497,3195...|(20000,[1497,3195...|  0.0|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----+
#
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |             comment|          difference|         probability|label|label_string|prediction|prediction_string|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+
# |preventing link r...|202010/05/01/%C2%...|[0.99999999999999...|  0.0|        safe|       0.0|             safe|
# +--------------------+--------------------+--------------------+-----+------------+----------+-----------------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
