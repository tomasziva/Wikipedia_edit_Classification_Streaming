# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from threading import Thread

class StreamingThread(Thread):
    def __init__(self, ssc):
        Thread.__init__(self)
        self.ssc = ssc
    def run(self):
        ssc.start()
        ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Tomas-PC:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType

# %%
from difflib import unified_diff

def make_diff(old, new):
    return '\n'.join([ l for l in unified_diff(old.split('\n'), new.split('\n')) if l.startswith('+') or l.startswith('-') ])

# %%
globals()['models_loaded'] = False

def predict(df):
    if any([x in df.diff.lower() for x in ['bad', 'lol', 'joke']]):
        return 'vandal'
    else:
        return 'safe'

predict_udf = udf(predict, StringType())

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df.show()
    
    # Tip: making a diff will probably help a lot as a feature in any model:
    diff = make_diff(df.first().text_old, df.first().text_new)
    df_withdiff = df.withColumn("diff", lit(diff))
    df_withdiff.select('diff').show()
    
    # Utilize our predict function
    df_withpreds = df_withdiff.withColumn("pred", predict_udf(
        struct([df_withdiff[x] for x in df_withdiff.columns])
    ))
    df_withpreds.show()
    
    # Normally, you wouldn't use a UDF (User Defined Function) Python function to predict (you can)
    # But an MLlib model you've built and saved with Spark
    # In this case, you need to prevent loading your model in every call to "process" as follows:
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = '***' # Replace '***' with:    [...].load('my_logistic_regression')
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model: 
    # df_result = globals()['my_model'].transform(df)
    # df_result.show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2020-04-22 21:19:30 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |clean up, remove ...| safe|GiantSnowman|{{Infobox footbal...|{{Infobox footbal...|           Marco Sas|//en.wikipedia.or...|
# |        →‎References| safe|     Moe1810|{{italic title}}
# ...|{{italic title}}
# ...|The Parent Trap (...|//en.wikipedia.or...|
# |Removed old logo ...| safe|  GOiSMTPwik|{{Infobox award
# |...|{{Infobox award
# |...|Sami Rohr Prize f...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|   ...|
# |---
#
# +++
#
# -|   ...|
# |---
#
# +++
#
# -|   ...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |clean up, remove ...| safe|GiantSnowman|{{Infobox footbal...|{{Infobox footbal...|           Marco Sas|//en.wikipedia.or...|---
#
# +++
#
# -|   ...|safe|
# |        →‎References| safe|     Moe1810|{{italic title}}
# ...|{{italic title}}
# ...|The Parent Trap (...|//en.wikipedia.or...|---
#
# +++
#
# -|   ...|safe|
# |Removed old logo ...| safe|  GOiSMTPwik|{{Infobox award
# |...|{{Infobox award
# |...|Sami Rohr Prize f...|//en.wikipedia.or...|---
#
# +++
#
# -|   ...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:19:40 =========
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|      title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+
# |→‎Physical charac...|  safe|        Sainsf|{{short descripti...|{{short descripti...|     Canada lynx|//en.wikipedia.or...|
# |clean up, remove ...|  safe|  GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|     Marcel Seip|//en.wikipedia.or...|
# |     (→‎Discography)|unsafe|151.52.155.134|{{BLP sources|dat...|{{BLP sources|dat...|Claudio Baglioni|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# |---
#
# +++
#
# -The ...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|      title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
# |→‎Physical charac...|  safe|        Sainsf|{{short descripti...|{{short descripti...|     Canada lynx|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |clean up, remove ...|  safe|  GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|     Marcel Seip|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# |     (→‎Discography)|unsafe|151.52.155.134|{{BLP sources|dat...|{{BLP sources|dat...|Claudio Baglioni|//en.wikipedia.or...|---
#
# +++
#
# -The ...|safe|
# +--------------------+------+--------------+--------------------+--------------------+----------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:19:50 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |        →‎References| safe|Yewtharaptor|{{short descripti...|{{short descripti...|    Navajo Sandstone|//en.wikipedia.or...|
# |                    | safe| Tiberiussan|{{about|the human...|{{about|the human...|Haplogroup D-CTS3946|//en.wikipedia.or...|
# |→‎Notable former ...| safe|GiantSnowman|{{See also|Bradfo...|{{See also|Bradfo...|     Manningham F.C.|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +== S...|
# |---
#
# +++
#
# +== S...|
# |---
#
# +++
#
# +== S...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |        →‎References| safe|Yewtharaptor|{{short descripti...|{{short descripti...|    Navajo Sandstone|//en.wikipedia.or...|---
#
# +++
#
# +== S...|safe|
# |                    | safe| Tiberiussan|{{about|the human...|{{about|the human...|Haplogroup D-CTS3946|//en.wikipedia.or...|---
#
# +++
#
# +== S...|safe|
# |→‎Notable former ...| safe|GiantSnowman|{{See also|Bradfo...|{{See also|Bradfo...|     Manningham F.C.|//en.wikipedia.or...|---
#
# +++
#
# +== S...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:20:00 =========
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|        name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
# |                    | safe|Garçon de chômage|{{about|the album...|{{about|the album...|           Speak Now|//en.wikipedia.or...|
# |                    | safe|            EriFr|{{Other uses|1954...|{{Other uses|1954...|1954–55 DDR-Oberliga|//en.wikipedia.or...|
# |→‎References:clea...| safe|     GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|      Malcolm Comrie|//en.wikipedia.or...|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| al...|
# |---
#
# +++
#
# -| al...|
# |---
#
# +++
#
# -| al...|
# +--------------------+
#
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|        name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                    | safe|Garçon de chômage|{{about|the album...|{{about|the album...|           Speak Now|//en.wikipedia.or...|---
#
# +++
#
# -| al...|safe|
# |                    | safe|            EriFr|{{Other uses|1954...|{{Other uses|1954...|1954–55 DDR-Oberliga|//en.wikipedia.or...|---
#
# +++
#
# -| al...|safe|
# |→‎References:clea...| safe|     GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|      Malcolm Comrie|//en.wikipedia.or...|---
#
# +++
#
# -| al...|safe|
# +--------------------+-----+-----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# ========= 2020-04-22 21:20:10 =========
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Places and geog...|  safe|       MattCHB|{{wiktionary|fram...|{{wiktionary|fram...|Fram (disambiguat...|//en.wikipedia.or...|
# |                    |vandal|172.10.235.186|{{short descripti...|{{short descripti...|Subnautica Below ...|//en.wikipedia.or...|
# |            clean up|  safe|  GiantSnowman|{{Use British Eng...|{{Use British Eng...|         Major Booth|//en.wikipedia.or...|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +*[[F...|
# |---
#
# +++
#
# +*[[F...|
# |---
#
# +++
#
# +*[[F...|
# +--------------------+
#
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|     name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Places and geog...|  safe|       MattCHB|{{wiktionary|fram...|{{wiktionary|fram...|Fram (disambiguat...|//en.wikipedia.or...|---
#
# +++
#
# +*[[F...|safe|
# |                    |vandal|172.10.235.186|{{short descripti...|{{short descripti...|Subnautica Below ...|//en.wikipedia.or...|---
#
# +++
#
# +*[[F...|safe|
# |            clean up|  safe|  GiantSnowman|{{Use British Eng...|{{Use British Eng...|         Major Booth|//en.wikipedia.or...|---
#
# +++
#
# +*[[F...|safe|
# +--------------------+------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:20:20 =========
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|          name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
# |Changed reference...| safe|SebastianDrawsStuff|{{good article}}
# ...|{{good article}}
# ...|        Sharon Kinne|//en.wikipedia.or...|
# |       -> lower case| safe|          WolfmanSF|{{short descripti...|{{short descripti...|       Bat-eared fox|//en.wikipedia.or...|
# |→‎Credits and per...| safe|           Kawayama|{{Infobox album
# |...|{{Infobox album
# |...|Bloodline (Recoil...|//en.wikipedia.or...|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| al...|
# |---
#
# +++
#
# -| al...|
# |---
#
# +++
#
# -| al...|
# +--------------------+
#
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |             comment|label|          name_user|            text_new|            text_old|          title_page|            url_page|                diff|  pred|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
# |Changed reference...| safe|SebastianDrawsStuff|{{good article}}
# ...|{{good article}}
# ...|        Sharon Kinne|//en.wikipedia.or...|---
#
# +++
#
# -| al...|vandal|
# |       -> lower case| safe|          WolfmanSF|{{short descripti...|{{short descripti...|       Bat-eared fox|//en.wikipedia.or...|---
#
# +++
#
# -| al...|vandal|
# |→‎Credits and per...| safe|           Kawayama|{{Infobox album
# |...|{{Infobox album
# |...|Bloodline (Recoil...|//en.wikipedia.or...|---
#
# +++
#
# -| al...|vandal|
# +--------------------+-----+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+
#
# ========= 2020-04-22 21:20:30 =========
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
# |     comment|label|       name_user|            text_new|            text_old|          title_page|            url_page|
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
# |     →‎Judge| safe|Chrisdoyleorwell|{{other uses|Nehe...|{{other uses|Nehe...|Nehemiah Donnella...|//en.wikipedia.or...|
# |    clean up| safe|    GiantSnowman|{{BLP sources|dat...|{{BLP sources|dat...|Martin Hunter (fo...|//en.wikipedia.or...|
# |→‎References| safe|         Moe1810|{{italic title}}
# ...|{{italic title}}
# ...|The Parent Trap (...|//en.wikipedia.or...|
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -He w...|
# |---
#
# +++
#
# -He w...|
# |---
#
# +++
#
# -He w...|
# +--------------------+
#
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |     comment|label|       name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |     →‎Judge| safe|Chrisdoyleorwell|{{other uses|Nehe...|{{other uses|Nehe...|Nehemiah Donnella...|//en.wikipedia.or...|---
#
# +++
#
# -He w...|safe|
# |    clean up| safe|    GiantSnowman|{{BLP sources|dat...|{{BLP sources|dat...|Martin Hunter (fo...|//en.wikipedia.or...|---
#
# +++
#
# -He w...|safe|
# |→‎References| safe|         Moe1810|{{italic title}}
# ...|{{italic title}}
# ...|The Parent Trap (...|//en.wikipedia.or...|---
#
# +++
#
# -He w...|safe|
# +------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:20:40 =========
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |(Undid revision 9...|unsafe|90.248.78.120|{{Use British Eng...|{{Use British Eng...| Enola Holmes (film)|//en.wikipedia.or...|
# |Jacskon->Jackson ...|  safe|     Mandarax|{{For|the defensi...|{{For|the defensi...|T. J. Jackson (wi...|//en.wikipedia.or...|
# |clean up,typo(s) ...|  safe| GiantSnowman|{{about||the Aust...|{{short descripti...|         Mark Yeates|//en.wikipedia.or...|
# |                    |  safe|     NJZombie|{{Use mdy dates|d...|{{Use mdy dates|d...|              Karmin|//en.wikipedia.or...|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -{{Us...|
# |---
#
# +++
#
# -{{Us...|
# |---
#
# +++
#
# -{{Us...|
# |---
#
# +++
#
# -{{Us...|
# +--------------------+
#
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |(Undid revision 9...|unsafe|90.248.78.120|{{Use British Eng...|{{Use British Eng...| Enola Holmes (film)|//en.wikipedia.or...|---
#
# +++
#
# -{{Us...|safe|
# |Jacskon->Jackson ...|  safe|     Mandarax|{{For|the defensi...|{{For|the defensi...|T. J. Jackson (wi...|//en.wikipedia.or...|---
#
# +++
#
# -{{Us...|safe|
# |clean up,typo(s) ...|  safe| GiantSnowman|{{about||the Aust...|{{short descripti...|         Mark Yeates|//en.wikipedia.or...|---
#
# +++
#
# -{{Us...|safe|
# |                    |  safe|     NJZombie|{{Use mdy dates|d...|{{Use mdy dates|d...|              Karmin|//en.wikipedia.or...|---
#
# +++
#
# -{{Us...|safe|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# ========= 2020-04-22 21:21:10 =========
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+
# |     comment|label|   name_user|            text_new|            text_old|        title_page|            url_page|
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+
# |            | safe|TheBlinkster|{{Divine Mercy}}
# ...|{{Divine Mercy}}
# ...|Divine Mercy image|//en.wikipedia.or...|
# |added a link| safe|    Blairall|{{distinguish|tex...|[[Image:SirWillia...|    Young baronets|//en.wikipedia.or...|
# |  →‎See also| safe|Yewtharaptor|{{Infobox rockuni...|{{Infobox rockuni...|    Kota Formation|//en.wikipedia.or...|
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Hyła...|
# |---
#
# +++
#
# -Hyła...|
# |---
#
# +++
#
# -Hyła...|
# +--------------------+
#
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |     comment|label|   name_user|            text_new|            text_old|        title_page|            url_page|                diff|pred|
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
# |            | safe|TheBlinkster|{{Divine Mercy}}
# ...|{{Divine Mercy}}
# ...|Divine Mercy image|//en.wikipedia.or...|---
#
# +++
#
# -Hyła...|safe|
# |added a link| safe|    Blairall|{{distinguish|tex...|[[Image:SirWillia...|    Young baronets|//en.wikipedia.or...|---
#
# +++
#
# -Hyła...|safe|
# |  →‎See also| safe|Yewtharaptor|{{Infobox rockuni...|{{Infobox rockuni...|    Kota Formation|//en.wikipedia.or...|---
#
# +++
#
# -Hyła...|safe|
# +------------+-----+------------+--------------------+--------------------+------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:21:20 =========
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+
# |             comment| label|   name_user|            text_new|            text_old|   title_page|            url_page|
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+
# |clean up,typo(s) ...|  safe|GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|Mark Stallard|//en.wikipedia.or...|
# |     (→‎Filmography)|unsafe|47.31.137.40|{{short descripti...|{{short descripti...|Ricco Fajardo|//en.wikipedia.or...|
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -| cl...|
# |---
#
# +++
#
# -| cl...|
# +--------------------+
#
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
# |             comment| label|   name_user|            text_new|            text_old|   title_page|            url_page|                diff|pred|
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
# |clean up,typo(s) ...|  safe|GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|Mark Stallard|//en.wikipedia.or...|---
#
# +++
#
# -| cl...|safe|
# |     (→‎Filmography)|unsafe|47.31.137.40|{{short descripti...|{{short descripti...|Ricco Fajardo|//en.wikipedia.or...|---
#
# +++
#
# -| cl...|safe|
# +--------------------+------+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:21:30 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |clean up,typo(s) ...| safe|GiantSnowman|{{Use Australian ...|{{Use Australian ...|      Mark Schwarzer|//en.wikipedia.or...|
# |→‎References:clea...| safe|    Headbomb|{{Multiple issues...|{{Multiple issues...|             ∞-topos|//en.wikipedia.or...|
# |Jainsim->Jainism ...| safe|    Mandarax|{{Use dmy dates|d...|{{Use dmy dates|d...|Jainism in Karnataka|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|bir...|
# |---
#
# +++
#
# -|bir...|
# |---
#
# +++
#
# -|bir...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |clean up,typo(s) ...| safe|GiantSnowman|{{Use Australian ...|{{Use Australian ...|      Mark Schwarzer|//en.wikipedia.or...|---
#
# +++
#
# -|bir...|safe|
# |→‎References:clea...| safe|    Headbomb|{{Multiple issues...|{{Multiple issues...|             ∞-topos|//en.wikipedia.or...|---
#
# +++
#
# -|bir...|safe|
# |Jainsim->Jainism ...| safe|    Mandarax|{{Use dmy dates|d...|{{Use dmy dates|d...|Jainism in Karnataka|//en.wikipedia.or...|---
#
# +++
#
# -|bir...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:21:40 =========
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |Updated infobox t...|  safe|      MattCHB|{{Infobox settlem...|{{Infobox settlem...|Wakefield, Massac...|//en.wikipedia.or...|
# |                    |unsafe|24.71.233.102|{{Redirect|Kohino...|{{Redirect|Kohino...|          Koh-i-Noor|//en.wikipedia.or...|
# |clean up, remove ...|  safe| GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|    Matthew Smithard|//en.wikipedia.or...|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -|nam...|
# |---
#
# +++
#
# -|nam...|
# |---
#
# +++
#
# -|nam...|
# +--------------------+
#
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Updated infobox t...|  safe|      MattCHB|{{Infobox settlem...|{{Infobox settlem...|Wakefield, Massac...|//en.wikipedia.or...|---
#
# +++
#
# -|nam...|safe|
# |                    |unsafe|24.71.233.102|{{Redirect|Kohino...|{{Redirect|Kohino...|          Koh-i-Noor|//en.wikipedia.or...|---
#
# +++
#
# -|nam...|safe|
# |clean up, remove ...|  safe| GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|    Matthew Smithard|//en.wikipedia.or...|---
#
# +++
#
# -|nam...|safe|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:21:50 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |        →‎Early life| safe| FeanorStar7|{{Use Irish Engli...|{{Use Irish Engli...|Arthur Wolfe, 1st...|//en.wikipedia.or...|
# |   typo in city name| safe|  Runner1928|Urbanized areas i...|Urbanized areas i...|List of Midwester...|//en.wikipedia.or...|
# |→‎Newport County:...| safe|GiantSnowman|{{EngvarB|date=Ju...|{{EngvarB|date=Ju...|Matthew Dolan (fo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Arth...|
# |---
#
# +++
#
# -Arth...|
# |---
#
# +++
#
# -Arth...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |        →‎Early life| safe| FeanorStar7|{{Use Irish Engli...|{{Use Irish Engli...|Arthur Wolfe, 1st...|//en.wikipedia.or...|---
#
# +++
#
# -Arth...|safe|
# |   typo in city name| safe|  Runner1928|Urbanized areas i...|Urbanized areas i...|List of Midwester...|//en.wikipedia.or...|---
#
# +++
#
# -Arth...|safe|
# |→‎Newport County:...| safe|GiantSnowman|{{EngvarB|date=Ju...|{{EngvarB|date=Ju...|Matthew Dolan (fo...|//en.wikipedia.or...|---
#
# +++
#
# -Arth...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:22:00 =========
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|           name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |     fixed cite j x2|  safe|     Bobamnertiopsis|{{Refimprove|date...|{{Refimprove|date...|Nyah nyah nyah ny...|//en.wikipedia.or...|
# |                    |unsafe|       41.114.117.90|[[File:Parade of ...|[[File:Parade of ...|     Basotho blanket|//en.wikipedia.or...|
# |Added under senso...|  safe|Myosotissylvaticabio|'''Lepidosaur her...|'''Lepidosaur her...|Lepidosaur herbivory|//en.wikipedia.or...|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -<ref...|
# |---
#
# +++
#
# -<ref...|
# |---
#
# +++
#
# -<ref...|
# +--------------------+
#
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|           name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |     fixed cite j x2|  safe|     Bobamnertiopsis|{{Refimprove|date...|{{Refimprove|date...|Nyah nyah nyah ny...|//en.wikipedia.or...|---
#
# +++
#
# -<ref...|safe|
# |                    |unsafe|       41.114.117.90|[[File:Parade of ...|[[File:Parade of ...|     Basotho blanket|//en.wikipedia.or...|---
#
# +++
#
# -<ref...|safe|
# |Added under senso...|  safe|Myosotissylvaticabio|'''Lepidosaur her...|'''Lepidosaur her...|Lepidosaur herbivory|//en.wikipedia.or...|---
#
# +++
#
# -<ref...|safe|
# +--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:22:10 =========
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Management care...|  safe|GiantSnowman|{{Use British Eng...|{{Use British Eng...|       Matthew Bates|//en.wikipedia.or...|
# |                    |unsafe| 70.59.36.72|{{short descripti...|{{short descripti...|  Brokeback Mountain|//en.wikipedia.or...|
# |→‎External links:...|  safe|GiantSnowman|{{Use British Eng...|{{Use British Eng...|Matt Palmer (foot...|//en.wikipedia.or...|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -On 2...|
# |---
#
# +++
#
# -On 2...|
# |---
#
# +++
#
# -On 2...|
# +--------------------+
#
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Management care...|  safe|GiantSnowman|{{Use British Eng...|{{Use British Eng...|       Matthew Bates|//en.wikipedia.or...|---
#
# +++
#
# -On 2...|safe|
# |                    |unsafe| 70.59.36.72|{{short descripti...|{{short descripti...|  Brokeback Mountain|//en.wikipedia.or...|---
#
# +++
#
# -On 2...|safe|
# |→‎External links:...|  safe|GiantSnowman|{{Use British Eng...|{{Use British Eng...|Matt Palmer (foot...|//en.wikipedia.or...|---
#
# +++
#
# -On 2...|safe|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:22:20 =========
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |       comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |              | safe| Anaitaallen|{{BLP refimprove|...|{{BLP refimprove|...|Phil Harvey (mana...|//en.wikipedia.or...|
# |    →‎See also| safe|Yewtharaptor|{{Infobox rockuni...|{{Infobox rockuni...|  Sachrang Formation|//en.wikipedia.or...|
# |→‎top:clean up| safe|GiantSnowman|{{distinguish|Mat...|{{short descripti...|            Matt Fry|//en.wikipedia.or...|
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# +
# +{{...|
# |---
#
# +++
#
# +
# +{{...|
# |---
#
# +++
#
# +
# +{{...|
# +--------------------+
#
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |       comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |              | safe| Anaitaallen|{{BLP refimprove|...|{{BLP refimprove|...|Phil Harvey (mana...|//en.wikipedia.or...|---
#
# +++
#
# +
# +{{...|safe|
# |    →‎See also| safe|Yewtharaptor|{{Infobox rockuni...|{{Infobox rockuni...|  Sachrang Formation|//en.wikipedia.or...|---
#
# +++
#
# +
# +{{...|safe|
# |→‎top:clean up| safe|GiantSnowman|{{distinguish|Mat...|{{short descripti...|            Matt Fry|//en.wikipedia.or...|---
#
# +++
#
# +
# +{{...|safe|
# +--------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:22:30 =========
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
# |           comment|label|       name_user|            text_new|            text_old|          title_page|            url_page|
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
# |Reversed vandalism| safe|     Librarian42|{{short descripti...|{{short descripti...|     Hurricane David|//en.wikipedia.or...|
# |                  | safe|YatesTucker00090|{{Infobox serial ...|{{Infobox serial ...|Alexander Spesivtsev|//en.wikipedia.or...|
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Hurr...|
# |---
#
# +++
#
# -Hurr...|
# +--------------------+
#
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |           comment|label|       name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Reversed vandalism| safe|     Librarian42|{{short descripti...|{{short descripti...|     Hurricane David|//en.wikipedia.or...|---
#
# +++
#
# -Hurr...|safe|
# |                  | safe|YatesTucker00090|{{Infobox serial ...|{{Infobox serial ...|Alexander Spesivtsev|//en.wikipedia.or...|---
#
# +++
#
# -Hurr...|safe|
# +------------------+-----+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:23:10 =========
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
# |Fixed spelling of...|  safe|    Vivafelis|{{Use mdy dates|d...|{{Use mdy dates|d...|          Myra Soble|//en.wikipedia.or...|
# |            clean up|  safe| GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|       Masood Fakhri|//en.wikipedia.or...|
# |                    |  safe|TheGEICOgecko|''Not to be confu...|''Not to be confu...|Hayesville High S...|//en.wikipedia.or...|
# |            (→‎Plot)|unsafe|    Thripweed|{{short descripti...|{{short descripti...|Indiana Jones and...|//en.wikipedia.or...|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Sobl...|
# |---
#
# +++
#
# -Sobl...|
# |---
#
# +++
#
# -Sobl...|
# |---
#
# +++
#
# -Sobl...|
# +--------------------+
#
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|    name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |Fixed spelling of...|  safe|    Vivafelis|{{Use mdy dates|d...|{{Use mdy dates|d...|          Myra Soble|//en.wikipedia.or...|---
#
# +++
#
# -Sobl...|safe|
# |            clean up|  safe| GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|       Masood Fakhri|//en.wikipedia.or...|---
#
# +++
#
# -Sobl...|safe|
# |                    |  safe|TheGEICOgecko|''Not to be confu...|''Not to be confu...|Hayesville High S...|//en.wikipedia.or...|---
#
# +++
#
# -Sobl...|safe|
# |            (→‎Plot)|unsafe|    Thripweed|{{short descripti...|{{short descripti...|Indiana Jones and...|//en.wikipedia.or...|---
#
# +++
#
# -Sobl...|safe|
# +--------------------+------+-------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:23:20 =========
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |         comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |→‎First painting| safe|TheBlinkster|{{Divine Mercy}}
# ...|{{Divine Mercy}}
# ...|  Divine Mercy image|//en.wikipedia.or...|
# |      →‎See also| safe|Yewtharaptor|{{short descripti...|{{short descripti...|     Posidonia Shale|//en.wikipedia.or...|
# |        clean up| safe|GiantSnowman|{{Other uses|Mich...|{{EngvarB|date=Ju...|Michael Proctor (...|//en.wikipedia.or...|
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -In 1...|
# |---
#
# +++
#
# -In 1...|
# |---
#
# +++
#
# -In 1...|
# +--------------------+
#
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |         comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎First painting| safe|TheBlinkster|{{Divine Mercy}}
# ...|{{Divine Mercy}}
# ...|  Divine Mercy image|//en.wikipedia.or...|---
#
# +++
#
# -In 1...|safe|
# |      →‎See also| safe|Yewtharaptor|{{short descripti...|{{short descripti...|     Posidonia Shale|//en.wikipedia.or...|---
#
# +++
#
# -In 1...|safe|
# |        clean up| safe|GiantSnowman|{{Other uses|Mich...|{{EngvarB|date=Ju...|Michael Proctor (...|//en.wikipedia.or...|---
#
# +++
#
# -In 1...|safe|
# +----------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:23:30 =========
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment| label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
# |                 ref|  safe|     Unoquha|'''Smeaton House'...|'''Smeaton House'...|       Smeaton House|//en.wikipedia.or...|
# |→‎Managerial stat...|  safe|GiantSnowman|{{lead too short|...|{{lead too short|...|Michael Nelson (f...|//en.wikipedia.or...|
# |                    |unsafe|71.213.33.10| arrived.
#
# Pennsy...|{{use mdy dates|d...|History of Pennsy...|//en.wikipedia.or...|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -[[Ar...|
# |---
#
# +++
#
# -[[Ar...|
# |---
#
# +++
#
# -[[Ar...|
# +--------------------+
#
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment| label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |                 ref|  safe|     Unoquha|'''Smeaton House'...|'''Smeaton House'...|       Smeaton House|//en.wikipedia.or...|---
#
# +++
#
# -[[Ar...|safe|
# |→‎Managerial stat...|  safe|GiantSnowman|{{lead too short|...|{{lead too short|...|Michael Nelson (f...|//en.wikipedia.or...|---
#
# +++
#
# -[[Ar...|safe|
# |                    |unsafe|71.213.33.10| arrived.
#
# Pennsy...|{{use mdy dates|d...|History of Pennsy...|//en.wikipedia.or...|---
#
# +++
#
# -[[Ar...|safe|
# +--------------------+------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+

# %%
ssc_t.stop()
# Out:
# ========= 2020-04-22 21:23:40 =========
# ----- Stopping... this may take a few seconds -----
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |               →‎Out| safe|       Bobly|{{Infobox footbal...|{{Infobox footbal...|1987–88 Real Madr...|//en.wikipedia.or...|
# |→‎References:clea...| safe|GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|Michael McHugh (f...|//en.wikipedia.or...|
# |         →‎top:comma| safe|CaroleHenson|{{Use dmy dates|d...|{{Use dmy dates|d...|      Lund Cathedral|//en.wikipedia.or...|
# |→‎Major intersect...| safe|MuzikMachine|{{Infobox road
# |p...|{{Infobox road
# |p...|Nova Scotia Trunk 22|//en.wikipedia.or...|
# |+Category:Recycli...| safe|  Wil540 art|{{Use mdy dates|d...|{{Use mdy dates|d...|Environmental iss...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -{{Fs...|
# |---
#
# +++
#
# -{{Fs...|
# |---
#
# +++
#
# -{{Fs...|
# |---
#
# +++
#
# -{{Fs...|
# |---
#
# +++
#
# -{{Fs...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |               →‎Out| safe|       Bobly|{{Infobox footbal...|{{Infobox footbal...|1987–88 Real Madr...|//en.wikipedia.or...|---
#
# +++
#
# -{{Fs...|safe|
# |→‎References:clea...| safe|GiantSnowman|{{Use dmy dates|d...|{{Use dmy dates|d...|Michael McHugh (f...|//en.wikipedia.or...|---
#
# +++
#
# -{{Fs...|safe|
# |         →‎top:comma| safe|CaroleHenson|{{Use dmy dates|d...|{{Use dmy dates|d...|      Lund Cathedral|//en.wikipedia.or...|---
#
# +++
#
# -{{Fs...|safe|
# |→‎Major intersect...| safe|MuzikMachine|{{Infobox road
# |p...|{{Infobox road
# |p...|Nova Scotia Trunk 22|//en.wikipedia.or...|---
#
# +++
#
# -{{Fs...|safe|
# |+Category:Recycli...| safe|  Wil540 art|{{Use mdy dates|d...|{{Use mdy dates|d...|Environmental iss...|//en.wikipedia.or...|---
#
# +++
#
# -{{Fs...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
#
# ========= 2020-04-22 21:23:50 =========
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
# |→‎Managerial care...| safe|GiantSnowman|{{Distinguish|Mik...|{{Distinguish|Mik...|Michael Flynn (fo...|//en.wikipedia.or...|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+
#
# +--------------------+
# |                diff|
# +--------------------+
# |---
#
# +++
#
# -Newp...|
# +--------------------+
#
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |             comment|label|   name_user|            text_new|            text_old|          title_page|            url_page|                diff|pred|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
# |→‎Managerial care...| safe|GiantSnowman|{{Distinguish|Mik...|{{Distinguish|Mik...|Michael Flynn (fo...|//en.wikipedia.or...|---
#
# +++
#
# -Newp...|safe|
# +--------------------+-----+------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+
